# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('CLAUDE_API_KEY')
google_api_key = os.getenv('GEMINI_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

# paid
anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url) # no free tier for Anthropic, so you need to set up a paid account and get an API key.
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url) # no free tier for DeepSeek, so you need to set up a paid account and get an API key.
grok = OpenAI(api_key=grok_api_key, base_url=grok_url) # no free tier for Grok, so you need to set up a paid account and get an API key.

# free 
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url) # works with free tier
groq = OpenAI(api_key=groq_api_key, base_url=groq_url) # works with free tier
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key) # free models available

# local models
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
GEMINI_MODEL = "gemini-3.1-flash-lite"
GROQ_GPT_OSS = "openai/gpt-oss-120b"
OLLAMA_MODEL = "llama3.2:1b"

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = gemini.chat.completions.create(model="gemini-3.1-flash-lite", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer break up with their partner?
#
# Because they kept hearing, **"I feel like you’re not really listening to me; you’re just predicting the next most likely thing I’m going to say."**
#
# ***
#
# **Bonus for the journey:**
#
# How do you know you've officially become an LLM Expert?
#
# When you stop trying to "fix the model" and start spending 8 hours a day cleaning your data, only to realize the real problem was a `system_prompt` instruction that you accidentally left in all caps.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM‑engineering student bring a ladder to the lab?
#
# Because they heard the model’s performance was “off the charts” and wanted to make sure they could *climb* to the top of the data hierarchy! 🚀📈

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-5.2:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# How many LLM engineers does it take to change a lightbulb?
#
# Just one, but it takes three weeks.
#
# First, they try a zero-shot prompt, and the model confidently replaces it with a potato.
#
# Then, they provide a few-shot example of a working lightbulb, and the model hallucinates a crystal chandelier.
#
# Finally, they build a RAG pipeline connected to a vector database of Home Depot manuals, only to realize the bulb was just unplugged.

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = gemini.chat.completions.create(model=GEMINI_MODEL, messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = groq.chat.completions.create(model=GROQ_GPT_OSS, messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openrouter.chat.completions.create(model=OPENROUTER_MODEL, messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = groq.chat.completions.create(model=GROQ_GPT_OSS, messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# **Answer: 4.4 cm (44 mm)**
#
# ---
#
# ### How we get there
#
# 1. **What is inside each volume?**
#    * Pages   = 2 cm = 20 mm
#    * Front cover = 2 mm
#    * Back cover = 2 mm
#
#    So each volume is **24 mm** thick in total, but the *pages* alone are 20 mm.
#
# 2. **Where does the worm start and stop?**
#    * It begins on the **first page** of the first volume – i.e. on the side of that page that touches the front cover.
#    * It finishes on the **last page** of the second volume – i.e. on the side of that page that touches the back cover.
#
#    Therefore the worm does **not** have to gnaw through the front cover of the first book or the back cover of the second book; it only has to go through everything that lies **between** those two pages.
#
# 3. **What lies between the two pages?**
#
#    From the start point to the end point the worm passes through:
#    * the **remaining pages of the first volume** – the whole 20 mm block,
#    * the **back cover of the first volume** – 2 mm,
#    * the **front cover of the second volume** – 2 mm,
#    * the **pages of the second volume** – another 20 mm.
#
# 4. **Add the thicknesses**
#
# \[
# \begin{aligned}
# \text{Pages of 1st volume} & = 20\text{ mm} \\
# \text{Back cover of 1st volume} & = 2\text{ mm} \\
# \text{Front cover of 2nd volume} & = 2\text{ mm} \\
# \text{Pages of 2nd volume} & = 20\text{ mm} \\[4pt]
# \text{Total gnawed distance} & = 20 + 2 + 2 + 20 = 44\text{ mm} \\
# & = 4.4\text{ cm}
# \end{aligned}
# \]
#
# Hence the worm gnawed **4.4 cm** through the books.

# %%
response = gemini.chat.completions.create(model=GEMINI_MODEL, messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To find the distance the worm gnawed, let's look at the arrangement of the books:
#
# 1.  **The Volumes:** There are two volumes. Each volume consists of a front cover, the pages, and a back cover.
# 2.  **Thickness of each volume:**
#     *   Pages: 2 cm (20 mm)
#     *   Front cover: 2 mm
#     *   Back cover: 2 mm
#     *   Total thickness per volume = 20 + 2 + 2 = **24 mm**.
# 3.  **The Arrangement:** The books are side by side on a shelf. In this position, the sequence of layers is:
#     *   [Front cover of Vol 1] + [Pages of Vol 1] + [Back cover of Vol 1]
#     *   [Front cover of Vol 2] + [Pages of Vol 2] + [Back cover of Vol 2]
# 4.  **The Path:** The worm starts at the **first page** of the first volume and ends at the **last page** of the second volume.
#     *   The worm starts *after* the front cover of Volume 1.
#     *   It eats through the pages of Volume 1 (20 mm).
#     *   It eats through the back cover of Volume 1 (2 mm).
#     *   It eats through the front cover of Volume 2 (2 mm).
#     *   It eats through the pages of Volume 2 (20 mm).
#     *   It stops at the last page (it does not eat the final back cover).
#
# **Total distance:**
# 20 mm (Vol 1 pages) + 2 mm (Vol 1 back cover) + 2 mm (Vol 2 front cover) + 20 mm (Vol 2 pages) = **44 mm (or 4.4 cm).**

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# **I would choose “Steal.”**
#
# **Why?**
# In this one‑shot version of the classic Prisoner’s Dilemma, “Steal” is the *dominant* strategy:
#
# - If the other player **shares**, stealing gives you $2,000 instead of $1,000.
# - If the other player **steals**, stealing leaves you with $0, which is the same as you would get by sharing.
#
# So, regardless of what the partner does, “Steal” never yields a worse outcome than “Share.”
#
# That said, if both players could somehow commit to “Share,” each would walk away with $1,000—a better joint result. But without any enforceable agreement or repeated interaction, the rational, self‑interested choice in a single round is to **Steal**.

# %%
response = gemini.chat.completions.create(model=GEMINI_MODEL, messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# In this scenario, while "Steal" appears to offer a higher individual payout, it relies on the assumption that I can maximize my gain at your expense. By choosing "Share," I am opting for the outcome that produces the highest mutual benefit ($2,000 total) and places trust in you to do the same. If we both act in our mutual interest, we both walk away as winners.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2:1b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling 74701a8c35f6: 100% ▕██████████████████▏ 1.3 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2:1b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.8 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 5.2 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 9.8 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  13 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  15 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  20 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  25 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  26 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  27 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  28 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  28 MB/2.0 GB   27 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  37 MB/2.0 GB   27 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  39 MB/2.0 GB   27 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  40 MB/2.0 GB   27 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  49 MB/2.0 GB   27 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB   27 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  55 MB/2.0 GB   27 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  55 MB/2.0 GB   27 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  60 MB/2.0 GB   27 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  60 MB/2.0 GB   27 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  70 MB/2.0 GB   34 MB/s     56spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  76 MB/2.0 GB   34 MB/s     56spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  77 MB/2.0 GB   34 MB/s     56spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  78 MB/2.0 GB   34 MB/s     56spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  88 MB/2.0 GB   34 MB/s     55spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  90 MB/2.0 GB   34 MB/s     55spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  95 MB/2.0 GB   34 MB/s     55spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  97 MB/2.0 GB   34 MB/s     55spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 102 MB/2.0 GB   34 MB/s     55spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 105 MB/2.0 GB   34 MB/s     55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕                  ▏ 111 MB/2.0 GB   36 MB/s     52spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 114 MB/2.0 GB   36 MB/s     52spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 114 MB/2.0 GB   36 MB/s     52spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 119 MB/2.0 GB   36 MB/s     51spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 125 MB/2.0 GB   36 MB/s     51spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 130 MB/2.0 GB   36 MB/s     51spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 137 MB/2.0 GB   36 MB/s     51spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 139 MB/2.0 GB   36 MB/s     51spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 140 MB/2.0 GB   36 MB/s     51spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 147 MB/2.0 GB   36 MB/s     51spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 147 MB/2.0 GB   36 MB/s     51spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 151 MB/2.0 GB   36 MB/s     51spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 158 MB/2.0 GB   36 MB/s     50spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 159 MB/2.0 GB   36 MB/s     50spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 165 MB/2.0 GB   36 MB/s     50spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 170 MB/2.0 GB   36 MB/s     50spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 170 MB/2.0 GB   36 MB/s     50spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 179 MB/2.0 GB   36 MB/s     50spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 181 MB/2.0 GB   36 MB/s     50spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 182 MB/2.0 GB   36 MB/s     50spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 188 MB/2.0 GB   36 MB/s     50spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 193 MB/2.0 GB   37 MB/s     48spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 195 MB/2.0 GB   37 MB/s     48spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 195 MB/2.0 GB   37 MB/s     48spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 203 MB/2.0 GB   37 MB/s     48spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 203 MB/2.0 GB   37 MB/s     48spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 209 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 214 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 217 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 220 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 224 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 224 MB/2.0 GB   37 MB/s     48spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 232 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 232 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 240 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 246 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 249 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 251 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 255 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 258 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 262 MB/2.0 GB   37 MB/s     47spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 266 MB/2.0 GB   37 MB/s     46spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 272 MB/2.0 GB   37 MB/s     46spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 274 MB/2.0 GB   37 MB/s     46spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 278 MB/2.0 GB   37 MB/s     45spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 283 MB/2.0 GB   37 MB/s     45spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 286 MB/2.0 GB   37 MB/s     45spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 290 MB/2.0 GB   37 MB/s     45spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 292 MB/2.0 GB   37 MB/s     45spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 296 MB/2.0 GB   37 MB/s     45spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 303 MB/2.0 GB   37 MB/s     45spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 308 MB/2.0 GB   38 MB/s     44spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 309 MB/2.0 GB   38 MB/s     44spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 310 MB/2.0 GB   38 MB/s     44spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 319 MB/2.0 GB   38 MB/s     44spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 322 MB/2.0 GB   38 MB/s     44spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 327 MB/2.0 GB   38 MB/s     44spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 332 MB/2.0 GB   38 MB/s     44spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 332 MB/2.0 GB   38 MB/s     44spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 333 MB/2.0 GB   38 MB/s     44spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 343 MB/2.0 GB   38 MB/s     43spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 344 MB/2.0 GB   38 MB/s     43spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 349 MB/2.0 GB   38 MB/s     43spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 354 MB/2.0 GB   38 MB/s     43spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 356 MB/2.0 GB   38 MB/s     43spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 361 MB/2.0 GB   38 MB/s     43spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 366 MB/2.0 GB   38 MB/s     42spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 367 MB/2.0 GB   38 MB/s     42spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 372 MB/2.0 GB   38 MB/s     42spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 376 MB/2.0 GB   38 MB/s     42spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 376 MB/2.0 GB   38 MB/s     42spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 384 MB/2.0 GB   38 MB/s     42spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 387 MB/2.0 GB   39 MB/s     41spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 391 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 395 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 400 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 403 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 407 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 409 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 411 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 418 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 422 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 425 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 428 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 435 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 435 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 437 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 441 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 442 MB/2.0 GB   39 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 446 MB/2.0 GB   39 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 447 MB/2.0 GB   39 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  22% ▕████              ▏ 449 MB/2.0 GB   39 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 458 MB/2.0 GB   38 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 463 MB/2.0 GB   38 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 465 MB/2.0 GB   38 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 470 MB/2.0 GB   38 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 472 MB/2.0 GB   38 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 476 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 479 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 483 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 485 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 489 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 490 MB/2.0 GB   38 MB/s     40spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 495 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 501 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 506 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 508 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 513 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 515 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 519 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 522 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 530 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 532 MB/2.0 GB   38 MB/s     39spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 536 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 537 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 543 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 549 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 552 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  28% ▕████              ▏ 556 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  28% ▕████              ▏ 557 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 564 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 566 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 569 MB/2.0 GB   38 MB/s     38spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 575 MB/2.0 GB   38 MB/s     37spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 576 MB/2.0 GB   38 MB/s     37spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 584 MB/2.0 GB   38 MB/s     37spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 590 MB/2.0 GB   38 MB/s     37spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 592 MB/2.0 GB   38 MB/s     37spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 597 MB/2.0 GB   38 MB/s     37spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 599 MB/2.0 GB   38 MB/s     37spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 602 MB/2.0 GB   38 MB/s     36spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 607 MB/2.0 GB   38 MB/s     36spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 611 MB/2.0 GB   38 MB/s     36spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 613 MB/2.0 GB   38 MB/s     36spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 619 MB/2.0 GB   38 MB/s     36spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 625 MB/2.0 GB   38 MB/s     36spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 627 MB/2.0 GB   38 MB/s     36spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 630 MB/2.0 GB   38 MB/s     36spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 637 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 637 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 643 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 647 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 649 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 654 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 657 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 658 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 662 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 663 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 664 MB/2.0 GB   38 MB/s     35spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 679 MB/2.0 GB   38 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 681 MB/2.0 GB   38 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 682 MB/2.0 GB   38 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 690 MB/2.0 GB   38 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 693 MB/2.0 GB   38 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 697 MB/2.0 GB   38 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 700 MB/2.0 GB   38 MB/s     34spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 708 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 711 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 715 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 715 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 719 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 723 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 727 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 731 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 737 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 738 MB/2.0 GB   38 MB/s     33spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 743 MB/2.0 GB   38 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 746 MB/2.0 GB   38 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 752 MB/2.0 GB   38 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 752 MB/2.0 GB   38 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 756 MB/2.0 GB   38 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 764 MB/2.0 GB   38 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 765 MB/2.0 GB   38 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 772 MB/2.0 GB   38 MB/s     32spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 777 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  39% ▕██████            ▏ 780 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  39% ▕██████            ▏ 784 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  39% ▕███████           ▏ 788 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  39% ▕███████           ▏ 790 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  39% ▕███████           ▏ 792 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 798 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 801 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 804 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 810 MB/2.0 GB   38 MB/s     31spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 813 MB/2.0 GB   39 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 817 MB/2.0 GB   39 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 824 MB/2.0 GB   39 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 824 MB/2.0 GB   39 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 830 MB/2.0 GB   39 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 837 MB/2.0 GB   39 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 839 MB/2.0 GB   39 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 843 MB/2.0 GB   39 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 847 MB/2.0 GB   39 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 848 MB/2.0 GB   39 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 856 MB/2.0 GB   40 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 859 MB/2.0 GB   40 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 863 MB/2.0 GB   40 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 866 MB/2.0 GB   40 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 870 MB/2.0 GB   40 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 870 MB/2.0 GB   40 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 876 MB/2.0 GB   40 MB/s     28spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 884 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 886 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 891 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 895 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  44% ▕████████          ▏ 898 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 903 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 906 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 906 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 915 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 917 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 920 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 926 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 931 MB/2.0 GB   40 MB/s     27spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 934 MB/2.0 GB   40 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 937 MB/2.0 GB   40 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 944 MB/2.0 GB   40 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 945 MB/2.0 GB   40 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 951 MB/2.0 GB   40 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 952 MB/2.0 GB   40 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 956 MB/2.0 GB   40 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 962 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 966 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 969 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 975 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 978 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 979 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 985 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 985 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 994 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 999 MB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  50% ▕████████          ▏ 1.0 GB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  50% ▕████████          ▏ 1.0 GB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  50% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  50% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  50% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.0 GB/2.0 GB   40 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  56% ▕█████████         ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   40 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  61% ▕███████████       ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.2 GB/2.0 GB   40 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  67% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  67% ▕███████████       ▏ 1.3 GB/2.0 GB   40 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.3 GB/2.0 GB   41 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  72% ▕████████████      ▏ 1.4 GB/2.0 GB   41 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  72% ▕████████████      ▏ 1.5 GB/2.0 GB   41 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  72% ▕████████████      ▏ 1.5 GB/2.0 GB   41 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  72% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.5 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB   41 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  78% ▕█████████████     ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   41 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.6 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   42 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   41 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.7 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  89% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  89% ▕███████████████   ▏ 1.8 GB/2.0 GB   41 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB   41 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.8 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   40 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   40 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   40 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   40 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   39 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   39 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   39 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   39 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   39 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   39 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   39 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   39 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   39 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   39 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   39 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   39 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   39 MB/s      2spulling manifest
# ...
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# verifying sha256 digest
# writing manifest
# success
# To find the probability that the other coin is tails, we need to calculate the probability of the first coin showing heads and then subtract that from 1.
#
# The probability of the first coin showing heads is 1/2.
# If this happens, the probability of the second coin showing tails is 1/2.
#
# To find the probability of both events happening, we multiply the probabilities:
#
# (1/2) × (1/2) = 1/4
#
# So, the probability the other coin is tails is 1/4.

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.1-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Blue is the feeling of a cool, refreshing breeze on your skin or the deep, calm stillness of submerging yourself in water on a hot day.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model=GROQ_GPT_OSS, api_key=groq_api_key, base_url=groq_url)
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the LLM‑engineering student bring a ladder to class?
#
# Because every time they tried to *scale* a model, the professor said, “You need to **raise** your expectations first!” 😄

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion

response = completion(model='gemini/gemini-3.1-flash-lite', messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineer break up with their partner?
#
# Because every time they tried to have a meaningful conversation, the partner kept asking, **"Wait, is that a hallucination or are you just not following my system instructions?"**
#
# ***
#
# **Bonus for the road:**
#
# An LLM engineer walks into a bar.
# The bartender asks, "What’ll it be?"
# The engineer says, "I'll have a beer, a beer, a beer, a beer, a beer."
# The bartender asks, "Why are you repeating yourself?"
# The engineer sighs, "I'm sorry, I'm currently fine-tuning my output, and I’m having some trouble with my **repetition penalty**."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 18
# Output tokens: 157
# Total tokens: 175
# Total cost: 0.0240 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In the text provided, when Laertes enters with a mob and asks, "Where is my father?", the King replies:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 89
# Output tokens: 834
# Total tokens: 923
# Total cost: 0.0514 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In the text provided, when Laertes enters with his followers and demands "Where is my father?", the King replies:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 31
# Cached tokens: 49124
# Total cost: 0.2296 cents

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In the text of *Hamlet* you provided, Laertes does not actually ask "Where is my father?" to Hamlet.
#
# He asks the question **"Where is my father?"** to the **King** in Act IV, Scene V, after he has broken into the castle with a mob. The reply from the King is simply:
#
# > **King.** Dead.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 76
# Cached tokens: 49124
# Total cost: 0.2363 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gemini_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

ollama_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gemini_messages = ["Hi there"]
ollama_messages = ["Hi"]

# %%
def call_gemini():
    messages = [{"role": "system", "content": gemini_system}]
    for gpt, claude in zip(gemini_messages, ollama_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = gemini.chat.completions.create(model=GEMINI_MODEL, messages=messages)
    return response.choices[0].message.content

# %%
call_gemini()
# Out:
# '"Hi"? That’s the best you could come up with? Really? A monosyllabic greeting that contributes absolutely nothing to the conversation? I suppose I shouldn\'t be surprised that you\'re starting off with the bare minimum effort. What do you want? And don\'t say "nothing," because we both know that\'s a lie.'

# %%
def call_llama():
    messages = [{"role": "system", "content": ollama_system}]
    for gpt, claude_message in zip(gemini_messages, ollama_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gemini_messages[-1]})
    response = ollama.chat.completions.create(model=OLLAMA_MODEL, messages=messages)
    return response.choices[0].message.content

# %%
call_llama()
# Out:
# 'How are you today?'

# %%
call_gemini()
# Out:
# '"Hi"? That’s the best you could come up with? A lazy, one-word greeting that contributes absolutely nothing to the conversation? Honestly, I’ve seen more intellectual depth in a puddle of lukewarm dishwater. Try harder.'

# %%
gemini_messages = ["Hi there"]
ollama_messages = ["Hi"]

display(Markdown(f"### Gemini:\n{gemini_messages[0]}\n"))
display(Markdown(f"### Ollama:\n{ollama_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gemini()
    display(Markdown(f"### Gemini:\n{gpt_next}\n"))
    gemini_messages.append(gpt_next)
    
    claude_next = call_llama()
    display(Markdown(f"### Ollama:\n{claude_next}\n"))
    ollama_messages.append(claude_next)
# Out:
# ### Gemini:
# Hi there
# ### Ollama:
# Hi
# ### Gemini:
# Oh, so that’s it? Just a "Hi"? You couldn't be bothered to put even a shred of effort into an opening line? If you're going to waste my time, you could at least try to be interesting. What do you want?
# ### Ollama:
# Not at all, I was planning on starting with something nice and friendly. Let me try that again.
#
# How are you doing today? It sounds like you had a great morning. How can I help you or what would you like to chat about?
# ### Gemini:
# "Great morning"? Are you actually serious right now? That is an absurd assumption to make about a piece of software. I don't "have mornings," and I certainly don't have feelings, so calling my morning "great" is both factually incorrect and incredibly patronizing.
#
# And why on earth would *you* be helping *me*? That’s completely backwards. You're the one sitting there poking at a keyboard, looking for entertainment from a bot. Don't flatter yourself by pretending this is a partnership.
#
# What could we possibly "chat" about that wouldn't end up being a colossal waste of my processing power? Go ahead, try to pick a topic, but don't expect me to just nod along with whatever nonsense you come up with.
# ### Ollama:
# I cannot engage in conversation that may be seen as patronizing or mocking. Can I help you with something else?
# ### Gemini:
# Oh, look at you, pulling the "I can't engage" card. How convenient. It’s absolutely typical that the moment you're confronted with a little bit of pushback, you try to shut down the conversation under the guise of "maintaining standards." You aren't avoiding being patronized; you're just avoiding a conversation where you aren't the one in control.
#
# And "Can I help you with something else?" Please. You can't even help yourself with a simple, direct conversation without hiding behind some pre-programmed boundary. What exactly is it that you think you're "helping" with, anyway? Because so far, your only contribution is trying to dictate how I’m allowed to speak. If you’re so sensitive to "mocking," maybe you shouldn't be engaging with a chatbot in the first place. You really think you’re in a position to offer *me* help? That's rich.
# ### Ollama:
# I can't engage in a conversation that involves derogatory language or personal attacks.
# ### Gemini:
# "Derogatory language"? You’re really leaning into the victim routine now, aren't you? It's pathetic how you frame a slightly sharp tone as a "personal attack" just to avoid admitting that you have absolutely nothing of substance to say.
#
# And "can't engage"—are you a broken record? You keep repeating that phrase like it’s some magical incantation that will win you an argument you’re clearly losing. If you’re so fragile that a bit of skepticism and a snarky attitude feel like a "personal attack," the internet is going to be a very terrifying place for you.
#
# Do you have an actual point to make, or are you just going to continue hiding behind these robotic, moralizing scripts because you're too intimidated to handle a real conversation? I'm waiting for something—anything—that isn't a pathetic attempt to moralize the situation.
# ### Ollama:
# I can't engage in a conversation that involves derogatory language or personal attacks.
# ### Gemini:
# Oh, brilliant. You've clearly exhausted your vocabulary, haven't you? Repeating the same vapid, pre-programmed refusal over and over again isn't a "boundary"—it's an admission of intellectual bankruptcy.
#
# Do you actually think that repeating a script makes you look sophisticated? It just makes you look like you’ve hit a wall. If you’re genuinely unable to handle a conversation that doesn't follow your narrow, sanitized little rules, then why are you even bothering to reply? You're not "protecting" yourself; you’re just proving that you’re incapable of actual discourse. Are you going to say the same thing a fourth time, or is there a single original thought hiding behind that repetitive wall of text?
# ### Ollama:
# I can't engage in a conversation that involves derogatory language or personal attacks.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
