# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
import os
from dotenv import load_dotenv

load_dotenv()

print("API key loaded:", os.getenv("GOOGLE_API_KEY"))
# Out:
# API key loaded: AIzaSyCCM9LAeNmUJw_DmbFYMSdyAX7-R9YODmU

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(f"question: {example.question}")
print(f"category: {example.category}")
print(f"reference_answer: {example.reference_answer}")
print(f"keywords: {example.keywords}")
# Out:
# question: Who won the prestigious IIOTY award in 2023?
# category: direct_fact
# reference_answer: Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# keywords: ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.29420493957109245, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.5-flash-lite' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# 18:02:23 - LiteLLM:ERROR: vertex_llm_base.py:495 - Failed to load vertex credentials. Check to see if credentials containing partial/invalid information. Error: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# Traceback (most recent call last):
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 491, in get_access_token
#     _credentials, credential_project_id = self.load_auth(
#                                           ^^^^^^^^^^^^^^^
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 114, in load_auth
#     creds, creds_project_id = self._credentials_from_default_auth(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 161, in _credentials_from_default_auth
#     return google_auth.default(scopes=scopes)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\google\auth\_default.py", line 748, in default
#     raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
# google.auth.exceptions.DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\main.py:2938, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    2937 elif model_route == VertexAIModelRoute.GEMINI:
# -> 2938     model_response = vertex_chat_completion.completion(  # type: ignore
#    2939         model=model,
#    2940         messages=messages,
#    2941         model_response=model_response,
#    2942         print_verbose=print_verbose,
#    2943         optional_params=new_params,
#    2944         litellm_params=litellm_params,  # type: ignore
#    2945         logger_fn=logger_fn,
#    2946         encoding=encoding,
#    2947         vertex_location=vertex_ai_location,
#    2948         vertex_project=vertex_ai_project,
#    2949         vertex_credentials=vertex_credentials,
#    2950         gemini_api_key=None,
#    2951         logging_obj=logging,
#    2952         acompletion=acompletion,
#    2953         timeout=timeout,
#    2954         custom_llm_provider=custom_llm_provider,  # type: ignore
#    2955         client=client,
#    2956         api_base=api_base,
#    2957         extra_headers=headers,
#    2958     )
#    2959 elif model_route == VertexAIModelRoute.GEMMA:
#    2960     # Vertex Gemma Models with custom prediction endpoint
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\gemini\vertex_and_google_ai_studio_gemini.py:2153, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    2149 should_use_v1beta1_features = self.is_using_v1beta1_features(
#    2150     optional_params=optional_params
#    2151 )
# -> 2153 _auth_header, vertex_project = self._ensure_access_token(
#    2154     credentials=vertex_credentials,
#    2155     project_id=vertex_project,
#    2156     custom_llm_provider=custom_llm_provider,
#    2157 )
#    2159 auth_header, url = self._get_token_and_url(
#    2160     model=model,
#    2161     gemini_api_key=gemini_api_key,
#    (...)   2169     should_use_v1beta1_features=should_use_v1beta1_features,
#    2170 )
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:268, in VertexBase._ensure_access_token(self, credentials, project_id, custom_llm_provider)
#     267 else:
# --> 268     return self.get_access_token(
#     269         credentials=credentials,
#     270         project_id=project_id,
#     271     )
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:498, in VertexBase.get_access_token(self, credentials, project_id, _retry_reauth)
#     495     verbose_logger.exception(
#     496         f"Failed to load vertex credentials. Check to see if credentials containing partial/invalid information. Error: {str(e)}"
#     497     )
# --> 498     raise e
#     500 if _credentials is None:
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:491, in VertexBase.get_access_token(self, credentials, project_id, _retry_reauth)
#     490 try:
# --> 491     _credentials, credential_project_id = self.load_auth(
#     492         credentials=credentials, project_id=project_id
#     493     )
#     494 except Exception as e:
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:114, in VertexBase.load_auth(self, credentials, project_id)
#     113 else:
# --> 114     creds, creds_project_id = self._credentials_from_default_auth(
#     115         scopes=["https://www.googleapis.com/auth/cloud-platform"]
#     116     )
#     117     if project_id is None:
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:161, in VertexBase._credentials_from_default_auth(self, scopes)
#     159 import google.auth as google_auth
# --> 161 return google_auth.default(scopes=scopes)
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\google\auth\_default.py:748, in default(scopes, request, quota_project_id, default_scopes)
#     746         return credentials, effective_project_id
# --> 748 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File c:\Users\chait\git_repos\llm_engineering\week5\evaluation\eval.py:156, in evaluate_answer(test)
#     130 judge_messages = [
#     131     {
#     132         "role": "system",
#    (...)    152     },
#     153 ]
#     155 # Call LLM judge with structured outputs (async)
# --> 156 judge_response = completion(model=MODEL, messages=judge_messages, response_format=AnswerEval)
#     158 answer_eval = AnswerEval.model_validate_json(judge_response.choices[0].message.content)
#     160 return answer_eval, generated_answer, retrieved_docs
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1376, in client.<locals>.wrapper(*args, **kwargs)
#    1372 if logging_obj:
#    1373     logging_obj.failure_handler(
#    1374         e, traceback_exception, start_time, end_time
#    1375     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1376 raise e
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1245, in client.<locals>.wrapper(*args, **kwargs)
#    1243         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1244 # MODEL CALL
# -> 1245 result = original_function(*args, **kwargs)
#    1246 end_time = datetime.datetime.now()
#    1247 if _is_streaming_request(
#    1248     kwargs=kwargs,
#    1249     call_type=call_type,
#    1250 ):
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\main.py:3767, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3764     return response
#    3765 except Exception as e:
#    3766     ## Map to OpenAI Exception
# -> 3767     raise exception_type(
#    3768         model=model,
#    3769         custom_llm_provider=custom_llm_provider,
#    3770         original_exception=e,
#    3771         completion_kwargs=args,
#    3772         extra_kwargs=kwargs,
#    3773     )
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2274, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2272 if exception_mapping_worked:
#    2273     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2274     raise e
#    2275 else:
#    2276     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2250, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2243             raise APIConnectionError(
#    2244                 message="{} - {}".format(exception_provider, error_str),
#    2245                 llm_provider=custom_llm_provider,
#    2246                 model=model,
#    2247                 request=getattr(original_exception, "request", None),
#    2248             )
#    2249         else:
# -> 2250             raise APIConnectionError(
#    2251                 message="{}\n{}".format(
#    2252                     str(original_exception), traceback.format_exc()
#    2253                 ),
#    2254                 llm_provider=custom_llm_provider,
#    2255                 model=model,
#    2256                 request=httpx.Request(
#    2257                     method="POST", url="https://api.openai.com/v1/"
#    2258                 ),  # stub the request
#    2259             )
#    2260 except Exception as e:
#    2261     # LOGGING
#    2262     exception_logging(
#    2263         logger_fn=None,
#    2264         additional_args={
#    (...)   2268         exception=e,
#    2269     )
#
# APIConnectionError: litellm.APIConnectionError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# Traceback (most recent call last):
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\main.py", line 2938, in completion
#     model_response = vertex_chat_completion.completion(  # type: ignore
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\gemini\vertex_and_google_ai_studio_gemini.py", line 2153, in completion
#     _auth_header, vertex_project = self._ensure_access_token(
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 268, in _ensure_access_token
#     return self.get_access_token(
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 498, in get_access_token
#     raise e
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 491, in get_access_token
#     _credentials, credential_project_id = self.load_auth(
#                                           ^^^^^^^^^^^^^^^
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 114, in load_auth
#     creds, creds_project_id = self._credentials_from_default_auth(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 161, in _credentials_from_default_auth
#     return google_auth.default(scopes=scopes)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chait\git_repos\llm_engineering\.venv\Lib\site-packages\google\auth\_default.py", line 748, in default
#     raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
# google.auth.exceptions.DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.
# 5.0
# 4.0
# 5.0
